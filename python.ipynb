# %%
# %pip install -r /workspaces/Celery-and-Fast-API/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 1.3 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.0 MB/s eta 0:00:00ta 0:00:01
# ...
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.0/426.0 kB 4.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 7.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 8.6 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 20.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.9/423.9 kB 14.9 MB/s eta 0:00:00
# ...

# %%
# !curl -X POST "http://localhost:8000/tasks/add_user" -H "Content-Type: application/json" -d '{"name":"taymoor","email":"syedtaymoor121@gmail.com"}'
# Out:
# {"task_id":"e2c18900-7c10-4dca-94e0-92d04f2e00cd"}

# %%
# !curl -X GET "http://localhost:8000/tasks/e2c18900-7c10-4dca-94e0-92d04f2e00cd"
# Out:
# {"task_id":"e2c18900-7c10-4dca-94e0-92d04f2e00cd","state":"SUCCESS","result":1}
